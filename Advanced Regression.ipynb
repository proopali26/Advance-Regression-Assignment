# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

import warnings as w
w.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Upgrad\Advanced Regression Assignment\train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df2 = df.drop(['MiscFeature','Fence','PoolQC','FireplaceQu','Alley'], axis = 1)

# %%
plt.figure(figsize = (20,7))
plt.subplot(2,3,1)
sns.boxplot('MSSubClass','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,2)
sns.boxplot('MSZoning','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,3)
sns.boxplot('Street','SalePrice',data = df2)


# plt.figure(figsize = (20,7))
# plt.subplot(2,3,4)
# sns.boxplot('Alley','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,5)
sns.boxplot('LotShape','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,6)
sns.boxplot('LandContour','SalePrice',data = df2)
# Out:
# <AxesSubplot:xlabel='LandContour', ylabel='SalePrice'>

# %%
plt.figure(figsize = (20,7))
plt.subplot(2,3,1)
sns.boxplot('Utilities','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,2)
sns.boxplot('LotConfig','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,3)
sns.boxplot('LandSlope','SalePrice',data = df2)


plt.figure(figsize = (20,7))
plt.subplot(2,3,4)
sns.boxplot('Neighborhood','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,5)
sns.boxplot('Condition1','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,6)
sns.boxplot('Condition2','SalePrice',data = df2)
# Out:
# <AxesSubplot:xlabel='Condition2', ylabel='SalePrice'>

# %%
plt.figure(figsize = (20,7))
sns.boxplot('Neighborhood','SalePrice',data = df2)
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='SalePrice'>

# %%
plt.figure(figsize = (20,7))
plt.subplot(2,3,1)
sns.boxplot('BldgType','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,2)
sns.boxplot('HouseStyle','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,3)
sns.boxplot('OverallQual','SalePrice',data = df2)


plt.figure(figsize = (20,7))
plt.subplot(2,3,4)
sns.boxplot('OverallCond','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,5)
sns.boxplot('RoofStyle','SalePrice',data = df2)

#plt.figure(figsize = (20,12))
plt.subplot(2,3,6)
sns.boxplot('RoofMatl','SalePrice',data = df2)
# Out:
# <AxesSubplot:xlabel='RoofMatl', ylabel='SalePrice'>

# %%
num_cols = df2.describe().columns

# %%
x_vars = df2[num_cols].drop(['SalePrice'],axis = 1).columns
y_vars = 'SalePrice'

# %%
plt.figure(figsize = (25,12))
sns.pairplot(x_vars = x_vars[:4], y_vars = y_vars, data = df2[num_cols],diag_kind = None)
sns.pairplot(x_vars = x_vars[4:8], y_vars = y_vars, data = df2[num_cols],diag_kind = None)
sns.pairplot(x_vars = x_vars[8:12], y_vars = y_vars, data = df2[num_cols],diag_kind = None)
sns.pairplot(x_vars = x_vars[12:16], y_vars = y_vars, data = df2[num_cols],diag_kind = None)
sns.pairplot(x_vars = x_vars[16:20], y_vars = y_vars, data = df2[num_cols],diag_kind = None)
sns.pairplot(x_vars = x_vars[20:24], y_vars = y_vars, data = df2[num_cols],diag_kind = None)
sns.pairplot(x_vars = x_vars[24:28], y_vars = y_vars, data = df2[num_cols],diag_kind = None)
sns.pairplot(x_vars = x_vars[28:32], y_vars = y_vars, data = df2[num_cols],diag_kind = None)
sns.pairplot(x_vars = x_vars[32:], y_vars = y_vars, data = df2[num_cols],diag_kind = None)
# sns.pairplot(x_vars = x_vars[24:], y_vars = y_vars, data = df2[num_cols],diag_kind = None)

# %%
df2['MSSubClass']=df2['MSSubClass'].apply(lambda x:str(x)+'_MSSubClass')
df2['MSZoning']=df2['MSZoning'].apply(lambda x:str(x)+'_MSZoning')
df2['Street']=df2['Street'].apply(lambda x:str(x)+'_Street')
df2['LotShape']=df2['LotShape'].apply(lambda x:str(x)+'_LotShape')
df2['LandContour']=df2['LandContour'].apply(lambda x:str(x)+'_LandContour')
df2['Utilities']=df2['Utilities'].apply(lambda x:str(x)+'_Utilities')
df2['LotConfig']=df2['LotConfig'].apply(lambda x:str(x)+'_LotConfig')
df2['LandSlope']=df2['LandSlope'].apply(lambda x:str(x)+'_LandSlope')
df2['Neighborhood']=df2['Neighborhood'].apply(lambda x:str(x)+'_Neighborhood')
df2['Condition1']=df2['Condition1'].apply(lambda x:str(x)+'_Condition1')
df2['Condition2']=df2['Condition2'].apply(lambda x:str(x)+'_Condition2')
df2['BldgType']=df2['BldgType'].apply(lambda x:str(x)+'_BldgType')
df2['HouseStyle']=df2['HouseStyle'].apply(lambda x:str(x)+'_HouseStyle')
df2['OverallQual']=df2['OverallQual'].apply(lambda x:str(x)+'_OverallQual')
df2['OverallCond']=df2['OverallCond'].apply(lambda x:str(x)+'_OverallCond')
df2['RoofStyle']=df2['RoofStyle'].apply(lambda x:str(x)+'_RoofStyle')
df2['RoofMatl']=df2['RoofMatl'].apply(lambda x:str(x)+'_RoofMatl')
df2['Exterior1st']=df2['Exterior1st'].apply(lambda x:str(x)+'_Exterior1st')
df2['Exterior2nd']=df2['Exterior2nd'].apply(lambda x:str(x)+'_Exterior2nd')
df2['MasVnrType']=df2['MasVnrType'].apply(lambda x:str(x)+'_MasVnrType')
df2['ExterQual']=df2['ExterQual'].apply(lambda x:str(x)+'_ExterQual')
df2['ExterCond']=df2['ExterCond'].apply(lambda x:str(x)+'_ExterCond')
df2['Foundation']=df2['Foundation'].apply(lambda x:str(x)+'_Foundation')
df2['BsmtQual']=df2['BsmtQual'].apply(lambda x:str(x)+'_BsmtQual')
df2['BsmtCond']=df2['BsmtCond'].apply(lambda x:str(x)+'_BsmtCond')
df2['BsmtExposure']=df2['BsmtExposure'].apply(lambda x:str(x)+'_BsmtExposure')
df2['BsmtFinType1']=df2['BsmtFinType1'].apply(lambda x:str(x)+'_BsmtFinType1')
df2['BsmtFinType2']=df2['BsmtFinType2'].apply(lambda x:str(x)+'_BsmtFinType2')
df2['Heating']=df2['Heating'].apply(lambda x:str(x)+'_Heating')
df2['HeatingQC']=df2['HeatingQC'].apply(lambda x:str(x)+'_HeatingQC')
df2['CentralAir']=df2['CentralAir'].apply(lambda x:str(x)+'_CentralAir')
df2['Electrical']=df2['Electrical'].apply(lambda x:str(x)+'_Electrical')
df2['KitchenQual']=df2['KitchenQual'].apply(lambda x:str(x)+'_KitchenQual')
df2['Functional']=df2['Functional'].apply(lambda x:str(x)+'_Functional')
# df2['FireplaceQu']=df2['FireplaceQu'].apply(lambda x:str(x)+'_FireplaceQu')
df2['GarageType']=df2['GarageType'].apply(lambda x:str(x)+'_GarageType')
df2['GarageFinish']=df2['GarageFinish'].apply(lambda x:str(x)+'_GarageFinish')
df2['GarageQual']=df2['GarageQual'].apply(lambda x:str(x)+'_GarageQual')
df2['GarageCond']=df2['GarageCond'].apply(lambda x:str(x)+'_GarageCond')
df2['PavedDrive']=df2['PavedDrive'].apply(lambda x:str(x)+'_PavedDrive')
# df2['PoolQC']=df2['PoolQC'].apply(lambda x:str(x)+'_PoolQC')
# df2['Fence']=df2['Fence'].apply(lambda x:str(x)+'_Fence')
# df2['Misc|Feature']=df2['MiscFeature'].apply(lambda x:str(x)+'_MiscFeature')
df2['SaleType']=df2['SaleType'].apply(lambda x:str(x)+'_SaleType')
df2['SaleCondition']=df2['SaleCondition'].apply(lambda x:str(x)+'_SaleCondition')

# %%
df_dummy_MSSubClass = pd.get_dummies(df2['MSSubClass'],drop_first = True)
df_dummy_MSZoning= pd.get_dummies(df2['MSZoning'],drop_first = True)
df_dummy_Street = pd.get_dummies(df2['Street'],drop_first = True)
df_dummy_LotShape = pd.get_dummies(df2['LotShape'],drop_first = True)
df_dummy_LandContour = pd.get_dummies(df2['LandContour'],drop_first = True)
df_dummy_Utilities = pd.get_dummies(df2['Utilities'],drop_first = True)
df_dummy_LotConfig = pd.get_dummies(df2['LotConfig'],drop_first = True)
df_dummy_LandSlope = pd.get_dummies(df2['LandSlope'],drop_first = True)
df_dummy_Neighborhood = pd.get_dummies(df2['Neighborhood'],drop_first = True)
df_dummy_Condition1 = pd.get_dummies(df2['Condition1'],drop_first = True)
df_dummy_Condition2 = pd.get_dummies(df2['Condition2'],drop_first = True)
df_dummy_BldgType = pd.get_dummies(df2['BldgType'],drop_first = True)
df_dummy_HouseStyle = pd.get_dummies(df2['HouseStyle'],drop_first = True)
df_dummy_OverallQual = pd.get_dummies(df2['OverallQual'],drop_first = True)
df_dummy_OverallCond = pd.get_dummies(df2['OverallCond'],drop_first = True)
df_dummy_RoofStyle = pd.get_dummies(df2['RoofStyle'],drop_first = True)

df_dummy_RoofMatl = pd.get_dummies(df2['RoofMatl'],drop_first = True)
df_dummy_Exterior1st = pd.get_dummies(df2['Exterior1st'],drop_first = True)
df_dummy_Exterior2nd = pd.get_dummies(df2['Exterior2nd'],drop_first = True)
df_dummy_MasVnrType = pd.get_dummies(df2['MasVnrType'],drop_first = True)
df_dummy_ExterQual = pd.get_dummies(df2['ExterQual'],drop_first = True)
df_dummy_ExterCond = pd.get_dummies(df2['ExterCond'],drop_first = True)
df_dummy_Foundation = pd.get_dummies(df2['Foundation'],drop_first = True)
df_dummy_BsmtQual = pd.get_dummies(df2['BsmtQual'],drop_first = True)
df_dummy_BsmtCond = pd.get_dummies(df2['BsmtCond'],drop_first = True)
df_dummy_BsmtExposure = pd.get_dummies(df2['BsmtExposure'],drop_first = True)
df_dummy_BsmtFinType1 = pd.get_dummies(df2['BsmtFinType1'],drop_first = True)
df_dummy_BsmtFinType2 = pd.get_dummies(df2['BsmtFinType2'],drop_first = True)
df_dummy_Heating = pd.get_dummies(df2['Heating'],drop_first = True)
df_dummy_HeatingQC = pd.get_dummies(df2['HeatingQC'],drop_first = True)
df_dummy_CentralAir = pd.get_dummies(df2['CentralAir'],drop_first = True)
df_dummy_Electrical = pd.get_dummies(df2['Electrical'],drop_first = True)

df_dummy_KitchenQual = pd.get_dummies(df2['KitchenQual'],drop_first = True)
df_dummy_Functional = pd.get_dummies(df2['Functional'],drop_first = True)
# df_dummy_FireplaceQu = pd.get_dummies(df2['FireplaceQu'],drop_first = True)
df_dummy_GarageType = pd.get_dummies(df2['GarageType'],drop_first = True)
df_dummy_GarageFinish = pd.get_dummies(df2['GarageFinish'],drop_first = True)
df_dummy_GarageQual = pd.get_dummies(df2['GarageQual'],drop_first = True)
df_dummy_GarageCond = pd.get_dummies(df2['GarageCond'],drop_first = True)
df_dummy_PavedDrive = pd.get_dummies(df2['PavedDrive'],drop_first = True)
# df_dummy_PoolQC = pd.get_dummies(df2['PoolQC'],drop_first = True)
# df_dummy_Fence = pd.get_dummies(df2['Fence'],drop_first = True)
# df_dummy_MiscFeature = pd.get_dummies(df2['MiscFeature'],drop_first = True)
df_dummy_SaleType = pd.get_dummies(df2['SaleType'],drop_first = True)
df_dummy_SaleCondition = pd.get_dummies(df2['SaleCondition'],drop_first = True)

# %%
df3 = pd.concat([df2,df_dummy_MSSubClass,df_dummy_MSZoning,df_dummy_Street,df_dummy_LotShape,df_dummy_LandContour,df_dummy_Utilities,df_dummy_LotConfig,df_dummy_LandSlope,df_dummy_Neighborhood,df_dummy_Condition1,df_dummy_Condition2,df_dummy_BldgType,df_dummy_HouseStyle
,df_dummy_OverallQual,df_dummy_OverallCond,df_dummy_RoofStyle,df_dummy_RoofMatl,df_dummy_Exterior1st,df_dummy_Exterior2nd,df_dummy_MasVnrType,df_dummy_ExterQual,df_dummy_ExterCond,df_dummy_Foundation,df_dummy_BsmtQual,df_dummy_BsmtCond,df_dummy_BsmtExposure,df_dummy_BsmtFinType1
,df_dummy_BsmtFinType2,df_dummy_Heating,df_dummy_HeatingQC,df_dummy_CentralAir,df_dummy_Electrical,df_dummy_KitchenQual,df_dummy_Functional,df_dummy_GarageType,df_dummy_GarageFinish,df_dummy_GarageQual,df_dummy_GarageCond,df_dummy_PavedDrive
,df_dummy_SaleType,df_dummy_SaleCondition], axis = 1)

# %%
df4 = df3.drop(['MSSubClass','MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle'
,'OverallQual','OverallCond','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1'
,'BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive'
,'SaleType','SaleCondition','Id'],axis = 1)
# 'Id' - just ID

# %%
df4.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        ...
#        'ConLw_SaleType', 'Con_SaleType', 'New_SaleType', 'Oth_SaleType',
#        'WD_SaleType', 'AdjLand_SaleCondition', 'Alloca_SaleCondition',
#        'Family_SaleCondition', 'Normal_SaleCondition',
#        'Partial_SaleCondition'],
#       dtype='object', length=272)

# %%
num_cols2 = df4.describe().columns

# %%
num_cols2 = [ 'LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
plt.figure(figsize = (20,12))
sns.heatmap(df4[num_cols2].corr(),annot = True,cmap = 'YlGnBu')
# Out:
# <AxesSubplot:>

# %%
df4['LotFrontage'] = df4['LotFrontage'].interpolate(method='linear', order=2)
df4['MasVnrArea'] = df4['MasVnrArea'].interpolate(method='linear', order=2)
df4['GarageYrBlt'] = df4['GarageYrBlt'].interpolate(method='linear', order=2)

# %%
df_train, df_test = train_test_split(df4)

# %%
x_train = df_train.drop('SalePrice',axis = 1)
y_train = df_train[['SalePrice']]

x_test = df_test.drop('SalePrice',axis = 1)
y_test = df_test[['SalePrice']]

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
df4.columns
# Out:
# Index(['LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        ...
#        'ConLw_SaleType', 'Con_SaleType', 'New_SaleType', 'Oth_SaleType',
#        'WD_SaleType', 'AdjLand_SaleCondition', 'Alloca_SaleCondition',
#        'Family_SaleCondition', 'Normal_SaleCondition',
#        'Partial_SaleCondition'],
#       dtype='object', length=272)

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(reg,50)

# %%
rfe = rfe.fit(x_train,y_train)

# %%
x_train.columns[rfe.support_]
# Out:
# Index(['90_MSSubClass', 'ClearCr_Neighborhood', 'Crawfor_Neighborhood',
#        'NoRidge_Neighborhood', 'PosN_Condition2', 'RRAe_Condition2',
#        'Duplex_BldgType', '1_OverallQual', '2_OverallQual', '3_OverallQual',
#        '4_OverallQual', '5_OverallQual', '6_OverallQual', '7_OverallQual',
#        '8_OverallQual', '9_OverallQual', '9_OverallCond', 'Shed_RoofStyle',
#        'CompShg_RoofMatl', 'Membran_RoofMatl', 'Metal_RoofMatl',
#        'Roll_RoofMatl', 'Tar&Grv_RoofMatl', 'WdShake_RoofMatl',
#        'WdShngl_RoofMatl', 'CemntBd_Exterior1st', 'ImStucc_Exterior1st',
#        'CmentBd_Exterior2nd', 'Fa_BsmtQual', 'Gd_BsmtQual', 'TA_BsmtQual',
#        'nan_BsmtQual', 'nan_BsmtCond', 'nan_BsmtFinType1', 'nan_BsmtFinType2',
#        'Po_HeatingQC', 'Fa_KitchenQual', 'Gd_KitchenQual', 'TA_KitchenQual',
#        'Sev_Functional', 'nan_GarageType', 'nan_GarageFinish', 'Gd_GarageQual',
#        'Po_GarageQual', 'TA_GarageQual', 'nan_GarageQual', 'Fa_GarageCond',
# ...

# %%
lr_rfe = sm.OLS(y_train,x_train)

# %%
x_train_rfe = sm.add_constant(x_train[x_train.columns[rfe.support_]])
# additional column dropping based on vif and p value
x_train_rfe = x_train_rfe.drop(['nan_BsmtQual'],axis = 1)

# %%
lr_rfe = sm.OLS(y_train,x_train_rfe)
lr_rfe_model = lr_rfe.fit()
lr_rfe_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.802
# Method:                 Least Squares   F-statistic:                     101.4
# Date:                Wed, 13 Apr 2022   Prob (F-statistic):               0.00
# Time:                        18:50:33   Log-Likelihood:                -13008.
# No. Observations:                1095   AIC:                         2.611e+04
# Df Residuals:                    1050   BIC:                         2.633e+04
# Df Model:                          44
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
y_train_pred = lr_rfe_model.predict(x_train_rfe)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.8095089722549829

# %%
x_train_rfe.columns
# Out:
# Index(['const', '90_MSSubClass', 'ClearCr_Neighborhood',
#        'Crawfor_Neighborhood', 'NoRidge_Neighborhood', 'PosN_Condition2',
#        'RRAe_Condition2', 'Duplex_BldgType', '1_OverallQual', '2_OverallQual',
#        '3_OverallQual', '4_OverallQual', '5_OverallQual', '6_OverallQual',
#        '7_OverallQual', '8_OverallQual', '9_OverallQual', '9_OverallCond',
#        'Shed_RoofStyle', 'CompShg_RoofMatl', 'Membran_RoofMatl',
#        'Metal_RoofMatl', 'Roll_RoofMatl', 'Tar&Grv_RoofMatl',
#        'WdShake_RoofMatl', 'WdShngl_RoofMatl', 'CemntBd_Exterior1st',
#        'ImStucc_Exterior1st', 'CmentBd_Exterior2nd', 'Fa_BsmtQual',
#        'Gd_BsmtQual', 'TA_BsmtQual', 'nan_BsmtCond', 'nan_BsmtFinType1',
#        'nan_BsmtFinType2', 'Po_HeatingQC', 'Fa_KitchenQual', 'Gd_KitchenQual',
#        'TA_KitchenQual', 'Sev_Functional', 'nan_GarageType',
#        'nan_GarageFinish', 'Gd_GarageQual', 'Po_GarageQual', 'TA_GarageQual',
# ...

# %%
x_test_rfe = sm.add_constant(x_test[x_train_rfe.drop('const',axis = 1).columns])

# %%
y_test_pred = lr_rfe_model.predict(x_test_rfe)

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.7107284353199532

# %%
sns.distplot(y_test.values - y_test_pred.values)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.linear_model import  LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(2)

# %%
x_poly = poly.fit_transform(x_train)

# %%
lrpoly = LinearRegression()

# %%
lrpoly.fit(x_poly, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lrpoly.predict(x_poly)

# %%
x_test_poly = poly.transform(x_test)

# %%
y_test_pred = lrpoly.predict(x_test_poly)
